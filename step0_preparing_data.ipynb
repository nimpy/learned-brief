# %%
"""
Extracting patches from images from ImageNet and KonIQ datasets. 

The patches are taken to be around some (randomly chosen) keypoints
detected by FAST detector.

The total amount of patches is 80748, and the ratio between training, 
validation, and test set is 8 : 1 : 1.
"""

# %%
from os import listdir
from os import system
import os
import random
from PIL import Image
import numpy as np
# import scipy.misc
import imageio
import cv2
import math

import matplotlib.pyplot as plt

# %%
dir_from = '/scratch/image_datasets/imagenet'
dir_all = '/scratch/image_datasets/2_for_learned_brief/ready/all'
patch_size = 56
patch_radius = 28
zfill_param = 6
stride = 8

flickr_fail_image = cv2.imread(dir_from + '/n00005787_71', 0)

# %%
fast = cv2.FastFeatureDetector_create()

# %%
# imagenet

# %%
counter = 0

dir_from = '/scratch/image_datasets/imagenet'
files = listdir(dir_from)
files_nr = len(files)
print(files_nr)

random.shuffle(files)
for i in range(files_nr):
    try:
        image = imageio.imread(dir_from + '/' + files[i])
        image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    except Exception as e:
        print(i, e)
        continue
    
    if image.shape == flickr_fail_image.shape and image[0].all() == flickr_fail_image[0].all() and image[1].all() == flickr_fail_image[1].all():
        print("Found Flickr fail image at", i)
        continue
    
    image = np.array(image)

    keypoints = fast.detect(image, None)
    random.shuffle(keypoints)
    
    # number of patches to be extracted from this image (calculated based on the image and patch size)
    total_nr_patches_in_this_image = int(math.floor(math.sqrt((image.shape[0] * image.shape[1]) / (patch_size**2)) / 2))
    print("total_nr_patches_in_this_image", total_nr_patches_in_this_image)

    counter_patches_in_this_image = 0
    for j, keypoint in enumerate(keypoints):
        keypoint = keypoints[j]
        x = int(keypoint.pt[1])
        y = int(keypoint.pt[0])
        
        # if the patch of size 56 x 56 around the keypoint completely fits inside the image
        if (x > patch_radius) and (x < image.shape[0] - patch_radius) and (y > patch_radius) and (y < image.shape[1] - patch_radius):
            patch = image[x - patch_radius: x + patch_radius, y - patch_radius: y + patch_radius]

            imageio.imwrite(dir_all + '/patch_brief_' + str(counter).zfill(zfill_param) + '.bmp', patch)
            counter_patches_in_this_image += 1
            counter += 1
            if counter_patches_in_this_image >= total_nr_patches_in_this_image:
                break
# Out:
# 4329
# total_nr_patches_in_this_image 2
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 3 Could not find a format to read the specified file in mode 'i'
# 4 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 7 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# total_nr_patches_in_this_image 4
# 9 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# total_nr_patches_in_this_image 3
# 11 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 18 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 4
# total_nr_patches_in_this_image 7
# 23 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 4
# total_nr_patches_in_this_image 4
# total_nr_patches_in_this_image 3
# 31 Could not find a format to read the specified file in mode 'i'
# 32 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 2
# total_nr_patches_in_this_image 3
# 37 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# 38 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 1
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 45 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 50 Could not find a format to read the specified file in mode 'i'
# 51 Could not find a format to read the specified file in mode 'i'
# 52 Could not find a format to read the specified file in mode 'i'
# 53 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 4
# total_nr_patches_in_this_image 3
# 56 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# total_nr_patches_in_this_image 3
# 58 Could not find a format to read the specified file in mode 'i'
# 59 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# 60 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# 62 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# 63 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# 65 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 4
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 2
# 70 Could not find a format to read the specified file in mode 'i'
# 71 Could not find a format to read the specified file in mode 'i'
# 72 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 4
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 77 Could not find a format to read the specified file in mode 'i'
# 78 Could not find a format to read the specified file in mode 'i'
# 79 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# total_nr_patches_in_this_image 3
# 81 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# 83 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 1
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 87 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 91 Could not find a format to read the specified file in mode 'i'
# Found Flickr fail image at 92
# total_nr_patches_in_this_image 16
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 1
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 99 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# 101 Could not find a format to read the specified file in mode 'i'
# 102 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# 104 Could not find a format to read the specified file in mode 'i'
# 105 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# 106 Could not find a format to read the specified file in mode 'i'
# 107 Could not find a format to read the specified file in mode 'i'
# 108 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 2
# total_nr_patches_in_this_image 4
# total_nr_patches_in_this_image 5
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 117 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 4
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 121 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 4
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 128 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# 129 Could not find a format to read the specified file in mode 'i'
# 130 Could not find a format to read the specified file in mode 'i'
# 131 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# 132 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 4
# total_nr_patches_in_this_image 3
# 135 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 4
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 141 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# total_nr_patches_in_this_image 4
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 147 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# 148 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# 150 Could not load ""
# Reason: "image file is truncated (17 bytes not processed)"
# Please see documentation at: http://pillow.readthedocs.io/en/latest/installation.html#external-libraries
# total_nr_patches_in_this_image 4
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 4
# 154 Could not find a format to read the specified file in mode 'i'
# 155 Could not find a format to read the specified file in mode 'i'
# 156 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 159 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# total_nr_patches_in_this_image 4
# 161 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# 163 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 4
# 166 Could not find a format to read the specified file in mode 'i'
# 167 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# 168 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# 169 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# total_nr_patches_in_this_image 3
# 171 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# total_nr_patches_in_this_image 4
# 173 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# total_nr_patches_in_this_image 3
# 175 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 178 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 2
# 180 Could not find a format to read the specified file in mode 'i'
# 181 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 2
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 5
# 186 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# 188 Could not find a format to read the specified file in mode 'i'
# 189 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 192 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# 193 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 196 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 202 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 4
# 206 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# 207 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 210 Could not find a format to read the specified file in mode 'i'
# 211 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# 213 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 1
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 220 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# 222 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 1
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 228 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 232 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 235 Could not find a format to read the specified file in mode 'i'
# 236 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 240 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# total_nr_patches_in_this_image 4
# 242 Could not find a format to read the specified file in mode 'i'
# 243 Could not find a format to read the specified file in mode 'i'
# 244 Could not find a format to read the specified file in mode 'i'
# 245 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 248 Could not find a format to read the specified file in mode 'i'
# 249 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 4
# total_nr_patches_in_this_image 2
# total_nr_patches_in_this_image 2
# 256 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# 257 Could not find a format to read the specified file in mode 'i'
# 258 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# total_nr_patches_in_this_image 4
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 262 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 4
# total_nr_patches_in_this_image 4
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 4
# total_nr_patches_in_this_image 3
# 268 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 5
# total_nr_patches_in_this_image 1
# 271 Could not find a format to read the specified file in mode 'i'
# 272 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# 274 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# total_nr_patches_in_this_image 1
# total_nr_patches_in_this_image 4
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 4
# 283 Could not find a format to read the specified file in mode 'i'
# 284 Could not find a format to read the specified file in mode 'i'
# 285 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 1
# total_nr_patches_in_this_image 3
# 288 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 0
# total_nr_patches_in_this_image 3
# 294 Could not find a format to read the specified file in mode 'i'
# 295 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# total_nr_patches_in_this_image 3
# 297 Could not find a format to read the specified file in mode 'i'
# 298 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 302 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# total_nr_patches_in_this_image 3
# 304 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# 306 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# 308 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 4
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 313 Could not find a format to read the specified file in mode 'i'
# 314 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 317 Could not find a format to read the specified file in mode 'i'
# 318 Could not find a format to read the specified file in mode 'i'
# 319 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 5
# 321 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 324 Could not find a format to read the specified file in mode 'i'
# 325 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 328 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 1
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 333 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# total_nr_patches_in_this_image 3
# 335 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# 336 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 339 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# 341 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 2
# total_nr_patches_in_this_image 3
# 347 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 0
# total_nr_patches_in_this_image 4
# 350 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 4
# total_nr_patches_in_this_image 3
# 353 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# 355 Could not find a format to read the specified file in mode 'i'
# 356 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 4
# total_nr_patches_in_this_image 3
# 359 Could not find a format to read the specified file in mode 'i'
# 360 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# 362 Could not find a format to read the specified file in mode 'i'
# 363 Could not find a format to read the specified file in mode 'i'
# 364 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 1
# 368 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# 369 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 372 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# 373 Could not find a format to read the specified file in mode 'i'
# 374 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# 376 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# 378 Could not find a format to read the specified file in mode 'i'
# 379 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# total_nr_patches_in_this_image 3
# 381 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# 383 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# total_nr_patches_in_this_image 3
# 385 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 388 Could not find a format to read the specified file in mode 'i'
# 389 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# total_nr_patches_in_this_image 3
# 391 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# total_nr_patches_in_this_image 4
# total_nr_patches_in_this_image 3
# 394 Could not find a format to read the specified file in mode 'i'
# 395 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 4
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 4
# total_nr_patches_in_this_image 4
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 4
# total_nr_patches_in_this_image 3
# 405 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 4
# total_nr_patches_in_this_image 4
# total_nr_patches_in_this_image 4
# total_nr_patches_in_this_image 1
# 411 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 1
# 413 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 416 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 1
# total_nr_patches_in_this_image 4
# total_nr_patches_in_this_image 3
# 420 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 4
# 423 Could not find a format to read the specified file in mode 'i'
# 424 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 428 Could not find a format to read the specified file in mode 'i'
# 429 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# 431 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 434 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 439 Could not find a format to read the specified file in mode 'i'
# 440 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# ...
# total_nr_patches_in_this_image 3
# 4218 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# total_nr_patches_in_this_image 4
# 4220 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 4223 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# 4224 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# 4225 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 2
# total_nr_patches_in_this_image 3
# 4228 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# 4229 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# total_nr_patches_in_this_image 2
# total_nr_patches_in_this_image 3
# 4232 Could not find a format to read the specified file in mode 'i'
# 4233 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# 4234 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 4
# total_nr_patches_in_this_image 2
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 4
# 4240 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 4243 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# total_nr_patches_in_this_image 2
# total_nr_patches_in_this_image 3
# 4246 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 4249 Could not find a format to read the specified file in mode 'i'
# 4250 Could not find a format to read the specified file in mode 'i'
# 4251 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 2
# 4254 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# 4256 Could not find a format to read the specified file in mode 'i'
# 4257 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# 4259 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# 4260 Could not find a format to read the specified file in mode 'i'
# 4261 Could not find a format to read the specified file in mode 'i'
# 4262 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 4
# 4265 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 4268 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 4271 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 4275 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# 4277 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 2
# total_nr_patches_in_this_image 4
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 1
# 4282 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 4286 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 4289 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 2
# 4293 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# total_nr_patches_in_this_image 4
# total_nr_patches_in_this_image 3
# 4296 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# 4300 Could not find a format to read the specified file in mode 'i'
# 4301 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 4
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 4
# total_nr_patches_in_this_image 3
# 4307 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 4
# total_nr_patches_in_this_image 2
# 4310 Could not find a format to read the specified file in mode 'i'
# 4311 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# 4312 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 1
# total_nr_patches_in_this_image 4
# total_nr_patches_in_this_image 3
# 4316 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# 4317 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# 4318 Could not find a format to read the specified file in mode 'i'
# 4319 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# 4320 Could not find a format to read the specified file in mode 'i'
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 5
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3
# total_nr_patches_in_this_image 3

# %%
counter
# Out:
# 8176

# %%
# koniq

# %%
counter = 8176

dir_from = '/scratch/image_datasets/koniq/1024x768/'
files = listdir(dir_from)
files_nr = len(files)
print(files_nr)

random.shuffle(files)
for i in range(files_nr):
    try:
        image = imageio.imread(dir_from + '/' + files[i])
        image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    except Exception as e:
        print(i, e)
        continue
    
    if image.shape == flickr_fail_image.shape and image[0].all() == flickr_fail_image[0].all() and image[1].all() == flickr_fail_image[1].all():
        print("Found Flickr fail image at", i)
        continue
    
    image = np.array(image)

    keypoints = fast.detect(image, None)
    random.shuffle(keypoints)
    
    # number of patches to be extracted from this image (calculated based on the image and patch size)
    total_nr_patches_in_this_image = int(math.floor(math.sqrt((image.shape[0] * image.shape[1]) / (patch_size**2)) / 2))
    print("total_nr_patches_in_this_image", total_nr_patches_in_this_image)

    counter_patches_in_this_image = 0
    for j, keypoint in enumerate(keypoints):
        keypoint = keypoints[j]
        x = int(keypoint.pt[1])
        y = int(keypoint.pt[0])
        
        # if the patch of size 56 x 56 around the keypoint completely fits inside the image
        if (x > patch_radius) and (x < image.shape[0] - patch_radius) and (y > patch_radius) and (y < image.shape[1] - patch_radius):
            patch = image[x - patch_radius: x + patch_radius, y - patch_radius: y + patch_radius]

            imageio.imwrite(dir_all + '/patch_brief_' + str(counter).zfill(zfill_param) + '.bmp', patch)
            counter_patches_in_this_image += 1
            counter += 1
            if counter_patches_in_this_image >= total_nr_patches_in_this_image:
                break
# Out:
# 10373
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# 805 OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1
#
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# ...
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7
# total_nr_patches_in_this_image 7

# %%
counter
# Out:
# 80748

# %%
# distribute the patches into train, validation and test directories, with 8 : 1 : 1 ratio

# %%
dir_base = '/scratch/image_datasets/2_for_learned_brief/ready'
dir_train = dir_base + '/train/class0'
dir_validation = dir_base + '/validation/class0'
dir_test = dir_base + '/test/class0'

files = os.listdir(dir_all)
files_count = len(files)

random.shuffle(files)

cutoff1 = int(files_count * 0.8)
cutoff2 = int(files_count * 0.9)
cutoff3 = files_count


for i in range(cutoff1):
    os.system("mv " + dir_all + "/" + files[i] + " " + dir_train + "/" + files[i])
    
for i in range(cutoff1, cutoff2):
    os.system("mv " + dir_all + "/" + files[i] + " " + dir_validation + "/" + files[i])
    
for i in range(cutoff2, cutoff3):
    os.system("mv " + dir_all + "/" + files[i] + " " + dir_test + "/" + files[i])
